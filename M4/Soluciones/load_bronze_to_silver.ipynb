# %% [markdown]
# # load_bronze_to_silver
#
# Este notebook se encarga de realizar la limpieza de los datos de bronze, incluyendo:
#
# - Nulos
# - Valores atípicos (outliers)
# - Duplicados
# - Tipado

# %% [markdown]
# ## Imports

# %%
import os

import pandas as pd

# %% [markdown]
# ## Parametros

# %%
bronze_path = os.path.join(
    os.curdir, "Data_Lake", "Bronze"
)
silver_path = os.path.join(
    os.curdir, "Data_Lake", "Silver"
)

# %%
bronze_file_name = "erp_bronze.parquet"

silver_file_name = "erp_silver.parquet"

# %%
bronze_file_path = os.path.join(
    bronze_path, bronze_file_name
)
silver_file_path = os.path.join(
    silver_path, silver_file_name
)

# %% [markdown]
# ## Main

# %% [markdown]
# ### Cargar los datos de bronze

# %%
bronze_erp_df = pd.read_parquet(bronze_file_path)

# %%
bronze_erp_df.head()
# Out:
#    id_cliente     nombre               email  edad     ciudad       salario  \
# 0           1  Cliente_1  cliente1@email.com  66.0   Valencia   2235.894632
# 1           2  Cliente_2  cliente2@email.com  None  Barcelona  44151.957628
# 2           3  Cliente_3  cliente3@email.com  75.0     Bilbao  35136.416478
# 3           4  Cliente_4  cliente4@email.com  35.0     Bilbao  13325.620084
# 4           5  Cliente_5  cliente5@email.com  38.0   Valencia  42037.063235
#
#                fecha_registro categoria       telefono activo  \
# 0  2016-03-22 22:25:26.825944         B  +34 674293979  False
# 1  2025-10-08 22:25:26.825944         E  +34 663639417      1
# 2  2017-05-12 22:25:26.825944         C  +34 652916829   True
# 3  2021-12-16 22:25:26.825944         C  +34 641535944   True
# 4  2018-11-05 22:25:26.825944         C  +34 602269798   True
#
#    puntos_fidelidad               ultima_compra           _BronzeTimestamp
# 0               NaN  2025-04-02 22:25:26.833943 2025-11-03 19:15:59.714757
# 1               NaN  2024-12-23 22:25:26.833943 2025-11-03 19:15:59.714757
# 2               NaN  2025-09-25 22:25:26.833943 2025-11-03 19:15:59.714757
# 3             200.0  2025-02-17 22:25:26.833943 2025-11-03 19:15:59.714757
# 4             200.0  2023-11-18 22:25:26.833943 2025-11-03 19:15:59.714757

# %% [markdown]
# ###  Tratar Nulos
#
# De cara a tratar los valores nulos, lo primero que debemos comprobar es que campos son críticos para la tabla.
#
# Si tenemos un "id" que usaremos para identificar a una fila de manera única, no puede ser nulo.
#
# De ahí en adelante debemos usar nuestro propio juicio para decidir que puede ser nulo y que no, y actuar en consecuencia:
#
# - Eliminando las filas con valores nulos en esa columna
# - Imputando los valores que faltan

# %%
# Compruebo si la columna de id contiene nulos
bronze_erp_df[bronze_erp_df['id_cliente'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [id_cliente, nombre, email, edad, ciudad, salario, fecha_registro, categoria, telefono, activo, puntos_fidelidad, ultima_compra, _BronzeTimestamp]
# Index: []

# %%
# Compruebo el resto de columnas
bronze_erp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_cliente        1020 non-null   int64
#  1   nombre            970 non-null    object
#  2   email             1020 non-null   object
#  3   edad              948 non-null    object
#  4   ciudad            895 non-null    object
#  5   salario           1020 non-null   float64
#  6   fecha_registro    1020 non-null   object
#  7   categoria         1020 non-null   object
#  8   telefono          1020 non-null   object
#  9   activo            1020 non-null   object
#  10  puntos_fidelidad  703 non-null    float64
#  11  ultima_compra     1020 non-null   object
#  12  _BronzeTimestamp  1020 non-null   datetime64[us]
# dtypes: datetime64[us](1), float64(2), int64(1), object(9)
# memory usage: 103.7+ KB

# %%
# Defino como voy a tratar los nulos en el resto de columnas
fill_values = {
    "puntos_fidelidad": bronze_erp_df['puntos_fidelidad'].mean(),
    "nombre": "Desconocido",
    "ciudad": "Desconocido"
}
# NOTE: En edad, dejaremos los nulos como estan

# %%
# Aplico la limpieza
bronze_erp_clean_df = bronze_erp_df.fillna(fill_values)

# %%
# Valido que se han corregido correctamente
bronze_erp_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_cliente        1020 non-null   int64
#  1   nombre            1020 non-null   object
#  2   email             1020 non-null   object
#  3   edad              948 non-null    object
#  4   ciudad            1020 non-null   object
#  5   salario           1020 non-null   float64
#  6   fecha_registro    1020 non-null   object
#  7   categoria         1020 non-null   object
#  8   telefono          1020 non-null   object
#  9   activo            1020 non-null   object
#  10  puntos_fidelidad  1020 non-null   float64
#  11  ultima_compra     1020 non-null   object
#  12  _BronzeTimestamp  1020 non-null   datetime64[us]
# dtypes: datetime64[us](1), float64(2), int64(1), object(9)
# memory usage: 103.7+ KB

# %% [markdown]
# ### Valores atipicos (outliers)
#
# Pese a que no se trata de errores en el dataset (como los nulos o los duplicados) los valores atípicos son registros en alguna columna que no tienen sentido lógico, como un valor para edad de un humano de 300 o -5.
#
# No hay una regla fuera de la lógica básica para detectar estos valores, pero hay distintas maneras de comprobarlos.

# %%
bronze_erp_clean_df['email'].value_counts(dropna=False)
# NOTE: Aquí podemos ver que tenemos 101 filas con un valor de "correo_no_valido"
# en la columna email
# Out:
# email
# correo_no_valido        101
# cliente211@email.com      2
# cliente205@email.com      2
# cliente152@email.com      2
# cliente283@email.com      2
#                        ...
# cliente996@email.com      1
# cliente997@email.com      1
# cliente998@email.com      1
# cliente999@email.com      1
# cliente4@email.com        1
# Name: count, Length: 901, dtype: int64

# %%
bronze_erp_clean_df['edad'].value_counts(dropna=False)
# NOTE: En el caso de edad, podemos ver que no solo tenemos nulos, sino
# que no todos los valores son un numero, debemos corregirlo.
# Out:
# edad
# veinticinco    102
# None            72
# 15.0            22
# 52.0            20
# 47.0            20
#               ...
# 79.0             8
# 24.0             8
# 25.0             8
# 57.0             7
# 45.0             6
# Name: count, Length: 67, dtype: int64

# %%
bronze_erp_clean_df['edad'] = bronze_erp_clean_df['edad'].replace("veinticinco",25)

# %%
# NOTE: Una vez solucionado el error de tipo, comprobamos los extremos del dataset
sorted(bronze_erp_clean_df['edad'].value_counts(dropna=False))
# Out:
# [6,
#  7,
#  8,
#  8,
#  8,
#  8,
#  8,
#  9,
#  9,
#  9,
#  10,
#  10,
#  10,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  17,
#  18,
#  18,
#  18,
#  19,
#  20,
#  20,
#  22,
#  72,
#  102]

# %%
# NOTE: Comprobamos si el tipo de los datos es correcto, y si no lo
# cambiamos
bronze_erp_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_cliente        1020 non-null   int64
#  1   nombre            1020 non-null   object
#  2   email             1020 non-null   object
#  3   edad              948 non-null    object
#  4   ciudad            1020 non-null   object
#  5   salario           1020 non-null   float64
#  6   fecha_registro    1020 non-null   object
#  7   categoria         1020 non-null   object
#  8   telefono          1020 non-null   object
#  9   activo            1020 non-null   object
#  10  puntos_fidelidad  1020 non-null   float64
#  11  ultima_compra     1020 non-null   object
#  12  _BronzeTimestamp  1020 non-null   datetime64[us]
# dtypes: datetime64[us](1), float64(2), int64(1), object(9)
# memory usage: 103.7+ KB

# %%
bronze_erp_clean_df['edad'] = bronze_erp_clean_df['edad'].astype("float")

# %%
bronze_erp_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_cliente        1020 non-null   int64
#  1   nombre            1020 non-null   object
#  2   email             1020 non-null   object
#  3   edad              948 non-null    float64
#  4   ciudad            1020 non-null   object
#  5   salario           1020 non-null   float64
#  6   fecha_registro    1020 non-null   object
#  7   categoria         1020 non-null   object
#  8   telefono          1020 non-null   object
#  9   activo            1020 non-null   object
#  10  puntos_fidelidad  1020 non-null   float64
#  11  ultima_compra     1020 non-null   object
#  12  _BronzeTimestamp  1020 non-null   datetime64[us]
# dtypes: datetime64[us](1), float64(3), int64(1), object(8)
# memory usage: 103.7+ KB

# %%
bronze_erp_clean_df['fecha_registro'].value_counts(dropna=False)
# NOTE: Aqui podemos ver que existen fechas inválidas (mes 13 dia 45)
# y que los timestamp (hora) son iguales
# Out:
# fecha_registro
# 2023-13-45                    51
# 2024-04-22 22:25:26.828945     3
# 2018-03-29 22:25:26.827944     2
# 2017-01-31 22:25:26.828945     2
# 2019-01-05 22:25:26.825944     2
#                               ..
# 2024-05-20 22:25:26.831943     1
# 2020-05-29 22:25:26.831943     1
# 2025-03-27 22:25:26.831943     1
# 2024-02-07 22:25:26.831943     1
# 2019-06-08 22:25:26.831943     1
# Name: count, Length: 930, dtype: int64

# %%
# Limpiar fechas erroneas
bronze_erp_dates_df = bronze_erp_clean_df[
    bronze_erp_clean_df['fecha_registro'] != '2023-13-45']

# %%
# Limpiar timestamp y convertir a fecha
bronze_erp_dates_df['fecha_registro'] = pd.to_datetime(bronze_erp_dates_df['fecha_registro']).dt.date
# Out:
# C:\Users\Alumno\AppData\Local\Temp\ipykernel_9936\593484380.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bronze_erp_dates_df['fecha_registro'] = pd.to_datetime(bronze_erp_dates_df['fecha_registro']).dt.date

# %%
sorted(bronze_erp_dates_df['salario'])
# NOTE: Aqui vemos que tenemos salarios negativos
# Out:
# [-49747.0817562402,
#  -25733.798108818195,
#  -20826.4212398459,
#  -18980.932957932066,
#  -18055.2833632101,
#  -12093.256642478147,
#  -11393.960989093262,
#  -7852.312053118163,
#  -7761.496535962935,
#  -7527.0429208179485,
#  -7028.143738264625,
#  -6786.103851483938,
#  -6475.703568932222,
#  -6324.245930707024,
#  -6246.776478187348,
#  -5765.350130344319,
#  -5242.924604877982,
#  -5033.590862499419,
#  -4153.690471494119,
#  -4078.288746389029,
#  -3060.5636287685998,
#  -2607.3188435204647,
#  -2484.678426061855,
#  -2354.7096704950964,
#  -2341.5154706222493,
#  -1996.995526057657,
#  -1468.431619630108,
#  387.93827496169615,
#  733.2228772671442,
#  1127.8248305600027,
#  1617.2362676449957,
#  1682.62741124471,
#  1976.9940006728284,
#  2162.4334357451407,
#  2235.89463157098,
#  2671.429010214688,
#  2776.9043343866324,
#  2915.9179063985066,
#  3320.5375018529485,
#  3410.8480752626747,
#  3490.5397033413574,
#  3885.272139474389,
#  3927.292914951846,
#  4557.313984566186,
#  4883.33604258456,
#  5111.330724162744,
#  5263.76499098666,
#  5527.487679237529,
#  5539.899488771036,
#  5609.833623351704,
#  5837.333166573801,
#  6034.321203398868,
#  6110.983734845871,
#  6514.921904576739,
#  6560.178221008824,
#  6650.76043804795,
#  6659.899008394754,
#  6714.338076224078,
#  6768.556168150819,
#  6924.450015478451,
#  7000.880944363129,
#  7177.08519911531,
#  7177.08519911531,
#  7257.962698451698,
#  7358.67129889856,
#  7795.738526888053,
#  8069.460427471717,
#  8235.40106338368,
#  8250.897307256211,
#  8383.010702150958,
#  8442.498588865612,
#  8685.231583908313,
#  8854.593456997995,
#  9037.226507341897,
#  9050.567163176587,
#  9180.809091501906,
#  9230.300689580949,
#  9256.995341186626,
#  9291.84982128886,
#  9349.626890428775,
#  9641.1715375983,
#  9856.434025955878,
#  9977.942426715344,
#  10031.553109288943,
#  10080.95229347322,
#  10103.689697115104,
#  10168.510200827135,
#  10245.666388547124,
#  10293.632794709509,
#  10295.02036541526,
#  10315.809219916213,
#  10315.809219916213,
#  10329.409123685213,
#  10350.342625764097,
#  10486.47365228811,
#  10596.620412490523,
#  10954.650193903391,
#  11246.30252819521,
#  11333.124002432494,
#  11380.215023583767,
#  11425.56467435931,
#  11427.558377916492,
#  11567.993721717936,
#  11602.768652872652,
#  11610.99952523696,
#  11666.433043866538,
#  11740.427162054806,
#  11812.844630281354,
#  11924.947183514589,
#  11984.547508846124,
#  12058.541522634305,
#  12083.403629914505,
#  12096.046345185066,
#  12102.680308518997,
#  12140.27141731949,
#  12172.69917110352,
#  12254.775100018123,
#  12288.269060244917,
#  12382.651762602924,
#  12471.835280150874,
#  12509.866663871624,
#  12518.359946699708,
#  12868.0402585298,
#  12868.101850557396,
#  12888.30886971164,
#  12919.980922936304,
#  13101.797815743044,
#  13135.611086912537,
#  13193.660101325746,
#  13279.719581100304,
#  13325.6200839191,
#  13349.428423628218,
#  13558.154628928973,
#  13569.81654214625,
#  13570.475773952145,
#  13570.748218552577,
#  13764.489918414649,
#  13804.639462464796,
#  13850.085982135057,
#  13871.031176604976,
#  13876.514140363195,
#  13897.984833908216,
#  13931.187754609116,
#  14053.364450258036,
#  14109.118042950842,
#  14109.216842862894,
#  14125.505925613095,
#  14134.265278949186,
#  14272.138301922105,
#  14438.198989293804,
#  14488.482158146038,
#  14555.479765081858,
#  14663.469306813508,
#  14841.088699400892,
#  15193.773445679662,
#  15200.415230406506,
#  15200.415230406506,
#  15315.671308390947,
#  15389.456653231846,
#  15393.75528062886,
#  15493.97634791894,
#  15602.580046295285,
#  15722.24287988064,
#  15773.326908657962,
#  15848.767274874312,
#  15933.302491951345,
#  16036.782087098936,
#  16065.300685160624,
#  16112.712252786312,
#  16153.010843132275,
#  16162.309044343769,
#  16163.509709827817,
#  16375.468035512917,
#  16557.158065250096,
#  16560.01789778247,
#  16567.358967823533,
#  16633.004870977704,
#  16793.070527663913,
#  16814.236722361653,
#  16874.618885156327,
#  16912.27026612193,
#  17069.251778932594,
#  17071.194329762657,
#  17079.244464648844,
#  17128.4168284771,
#  17140.88370387411,
#  17167.329630326203,
#  17363.992761948048,
#  17427.05528985722,
#  17492.472248402966,
#  17527.47085565855,
#  17532.45171293003,
#  17566.07878701117,
#  17573.05846548408,
#  17625.474346012717,
#  17649.611931323656,
#  17720.749805931348,
#  17738.62235968257,
#  17775.540231518356,
#  17831.801792166778,
#  17877.096224243673,
#  17940.34389538895,
#  18006.91618150974,
#  18219.7028623192,
#  18239.46187509039,
#  18265.96469510508,
#  18265.96469510508,
#  18284.69356102664,
#  18314.792354494617,
#  18352.772879105352,
#  18463.27164836416,
#  18463.27164836416,
#  18469.705288949364,
#  18495.200847964174,
#  18566.378068056267,
#  18578.067518715747,
#  18593.99888500041,
#  18636.75433141077,
#  18700.52663492164,
#  18761.895634286117,
#  18850.6499555255,
#  18920.53781960896,
#  19004.909050850383,
#  19039.77054294329,
#  19058.17955835392,
#  19167.280381095417,
#  19232.649209224168,
#  19237.722208783773,
#  19247.006694636133,
#  19261.24723862201,
#  19359.745680959,
#  19363.10422647131,
#  19397.14298909705,
#  19474.386028126875,
#  19494.7678881307,
#  19533.99325047579,
#  19545.903823791425,
#  19567.9615301758,
#  19591.97518787973,
#  19610.07663254846,
#  19625.736452716486,
#  19636.793815706853,
#  19661.56394674715,
#  19696.263663112688,
#  19705.213865263264,
#  19769.484252010283,
#  19822.059969528866,
#  19837.865145042557,
#  19852.42317826296,
#  19860.205905384035,
#  19937.45944899758,
#  20146.34099253789,
#  20270.06119426695,
#  20355.02664778682,
#  20424.84209785496,
#  20566.06663216961,
#  20581.25216102876,
#  20645.918476061903,
#  20687.32171076036,
#  20793.04684735685,
#  20889.816018518177,
#  20948.665518604164,
#  20971.69183198149,
#  21022.595749254964,
#  21073.47308767921,
#  21080.91249240742,
#  21142.828971834373,
#  21142.828971834373,
#  21145.86774960326,
#  21187.532775423853,
#  21248.814661978056,
#  21281.472403757514,
#  21288.333172440427,
#  21299.579962673408,
#  21300.944461306117,
#  21311.1715073573,
#  21313.795372808552,
#  21483.67405238709,
#  21492.11371780983,
#  21495.585366701343,
#  21498.072404308517,
#  21676.92430843864,
#  21707.474480682307,
#  21736.332261677195,
#  21739.09463867044,
#  21793.57053919348,
#  21806.097434536543,
#  21861.015533533857,
#  21900.98310691724,
#  22003.441127032296,
#  22042.385655927646,
#  22070.06994994257,
#  22075.815398970302,
#  22090.71083639669,
#  22105.582031595397,
#  22140.051398169653,
#  22171.472787252675,
#  22202.19912676869,
#  22223.956508767173,
#  22256.159760943094,
#  22256.368694862595,
#  22265.03949236683,
#  22315.054883665445,
#  22328.241666746533,
#  22384.80326301507,
#  22390.00836917181,
#  22400.84239950573,
#  22461.008090906515,
#  22510.54140642004,
#  22562.12383894781,
#  22593.441333772516,
#  22593.60086459316,
#  22614.73481790659,
#  22620.399462913203,
#  22663.578211216394,
#  22734.585835914662,
#  22769.298077576743,
#  22878.39531774438,
#  22898.12859551461,
#  22922.106083498045,
#  22956.71731408,
#  22960.898928678293,
#  22971.256021349764,
#  22977.25813036433,
#  23035.194832538004,
#  23113.63404668121,
#  23126.75221049137,
#  23144.424962064048,
#  23248.48299464664,
#  23370.477041186867,
#  23471.93507074549,
#  23477.613571346326,
#  23501.101747686844,
#  23757.08995904789,
#  23794.362484880723,
#  23818.91316474316,
#  23845.778460435045,
#  23903.066681559576,
#  24025.186409640573,
#  24037.052685668103,
#  24158.731837604435,
#  24239.51733179789,
#  24303.63990029637,
#  24310.05120242507,
#  24328.708485249983,
#  24335.23707998165,
#  24340.826911744665,
#  24392.58908925852,
#  24442.40547465721,
#  24532.99106219657,
#  24536.962747680936,
#  24558.93129773328,
#  24575.320834715145,
#  24579.21349227243,
#  24592.28674914165,
#  24597.096080850784,
#  24599.51828017709,
#  24643.464452883905,
#  24652.92543947504,
#  24800.50224763767,
#  24815.85727954952,
#  24848.83350618049,
#  24914.320451853917,
#  24917.10494850961,
#  24958.890207749453,
#  25071.97637305902,
#  25167.90637214904,
#  25188.37750640582,
#  25206.648565213796,
#  25214.884998707643,
#  25247.673580623035,
#  25338.68292328801,
#  25393.57672933348,
#  25404.69808843036,
#  25454.525385029563,
#  25462.99742688973,
#  25471.73242214172,
#  25704.12189754835,
#  25769.71603855447,
#  25864.09121299011,
#  25867.345642973985,
#  25927.13286762926,
#  25941.00162504945,
#  25972.97594562532,
#  26070.503455221708,
#  26086.316008243048,
#  26123.989196892475,
#  26136.896699073768,
#  26161.779634942024,
#  26193.79978758624,
#  26245.21932400509,
#  26410.54834800872,
#  26421.99829736,
#  26468.765671301677,
#  26506.59880144352,
#  26539.493802067827,
#  26661.872461284027,
#  26703.89544895685,
#  26720.689332619037,
#  26734.03523267329,
#  27018.914459750653,
#  27032.92971155241,
#  27070.53456626859,
#  27152.962203788687,
#  27163.7779625719,
#  27204.553951845217,
#  27208.164783717457,
#  27380.432222851046,
#  27384.374544520346,
#  27391.70037616248,
#  27455.488213572677,
#  27458.261437749487,
#  27466.48829538843,
#  27468.04819946782,
#  27479.174014674525,
#  27533.75339307928,
#  27683.01721698036,
#  27795.01826704391,
#  27842.313436320543,
#  27847.314834668825,
#  27917.061192079924,
#  28093.02837522004,
#  28110.915405797496,
#  28143.1561828362,
#  28144.074955992404,
#  28154.791149646346,
#  28201.9117886569,
#  28314.69162794429,
#  28350.934269447247,
#  28379.434503161243,
#  28401.078586280222,
#  28409.07136442942,
#  28432.779804347003,
#  28457.467196634007,
#  28472.763869556456,
#  28540.3771684196,
#  28571.323826619824,
#  28588.46027310725,
#  28685.42613275284,
#  28813.818785904725,
#  28820.73542187772,
#  28825.940042948776,
#  28877.19921097729,
#  28904.49780271796,
#  28928.315143518288,
#  28989.13146422709,
#  28992.246290071245,
#  29002.07223671951,
#  29050.66318291555,
#  29051.648152755617,
#  29207.100685630496,
#  29359.443079150748,
#  29384.768684948045,
#  29403.91642790738,
#  29451.999751220843,
#  29460.06882034137,
#  29479.450199551648,
#  29547.425000562976,
#  29548.267993498503,
#  29584.93998608608,
#  29725.24710835723,
#  29754.01835616317,
#  29787.029633829912,
#  29848.261327966327,
#  29884.061666178928,
#  29960.974985864723,
#  30087.785050880648,
#  30102.04647589157,
#  30150.34953363381,
#  30281.70456474674,
#  30372.785073669664,
#  30391.83647309589,
#  30419.2718286669,
#  30446.68894851936,
#  30457.432571303973,
#  30495.40564448696,
#  30527.218221367628,
#  30866.933783778288,
#  30893.29452470423,
#  30900.435086280184,
#  30947.481889607603,
#  31046.688202481968,
#  31135.08441070853,
#  31175.230034438908,
#  31185.001254165934,
#  31216.503660600323,
#  31234.94830075631,
#  31287.60595089755,
#  31412.69162520613,
#  31424.99825245556,
#  31498.583158536145,
#  31592.681517333174,
#  31657.35808049203,
#  31662.316427007045,
#  31664.34144102065,
#  31708.794421511546,
#  31886.267588031304,
#  31926.77606396629,
#  31939.604627495108,
#  31971.87601171831,
#  32130.76416486914,
#  32189.42414569725,
#  32243.962171103307,
#  32252.019510093272,
#  32270.96531839811,
#  32314.756899544213,
#  32421.59794931548,
#  32445.91601144124,
#  32452.1621875118,
#  32453.60003382982,
#  32536.860751486354,
#  32562.47847619946,
#  32564.564573523287,
#  32581.820585031644,
#  32610.278349309054,
#  32647.30965543938,
#  32691.25219246903,
#  32695.776796476737,
#  32723.80268923185,
#  32742.10363808005,
#  32811.29820785155,
#  32826.24012446142,
#  32839.31841353333,
#  32839.31841353333,
#  32844.42184958179,
#  32900.93674742611,
#  32930.62926527616,
#  33075.40030592818,
#  33136.03845176798,
#  33147.27193065063,
#  33148.68134462805,
#  33158.550509376975,
#  33174.614662629734,
#  33191.1725768961,
#  33258.214644710155,
#  33449.316717633184,
#  33464.00161244992,
#  33474.720232259744,
#  33485.404165258,
#  33512.063206699444,
#  33546.37014393673,
#  33654.487500110605,
#  33659.464819188666,
#  33679.16756667645,
#  33686.0097438203,
#  33705.3996540767,
#  33712.46695255816,
#  33773.56627248479,
#  33888.2702751489,
#  33903.9833755159,
#  33958.416456810286,
#  34100.645219164006,
#  34100.645219164006,
#  34155.941256562684,
#  34171.59028637941,
#  34174.93591830322,
#  34233.11464334902,
#  34289.774110836894,
#  34371.74884817709,
#  34459.64468521263,
#  34468.42374718035,
#  34470.78315160763,
#  34502.33377493588,
#  34502.88243900292,
#  34525.42702419061,
#  34535.00612645001,
#  34535.98266357337,
#  34556.70464235758,
#  34681.19128229504,
#  34751.130882066565,
#  34837.36073509226,
#  34877.00472947657,
#  34911.29657476482,
#  34939.73677727664,
#  35017.48802667177,
#  35042.40069414062,
#  35082.97735577614,
#  35101.76559606967,
#  35124.43829053672,
#  35125.93372110652,
#  35136.41647831912,
#  35157.67234686449,
#  35237.58810467785,
#  35273.219382388335,
#  35298.11091761765,
#  35300.89256395362,
#  35336.89462391493,
#  35417.17155520303,
#  35453.1891103104,
#  35582.53022208143,
#  35616.5448893186,
#  35669.42189905311,
#  35698.01776063622,
#  35700.711951885394,
#  35705.37795575874,
#  35727.58591261476,
#  35733.82408717378,
#  35736.62126728948,
#  35856.035158744,
#  35886.97711689883,
#  35908.67959854229,
#  35922.386166115524,
#  36091.27795524351,
#  36157.13765841685,
#  36272.80617701623,
#  36273.09919131804,
#  36320.39352073502,
#  36330.19741060453,
#  36379.93590714891,
#  36397.43728379533,
#  36439.96532729853,
#  36458.59008141074,
#  36482.88977198107,
#  36494.65024091597,
#  36496.80802015791,
#  36546.37694239618,
#  36642.09571531373,
#  36731.70777849775,
#  36735.16445128404,
#  36774.490524743946,
#  36824.5783590146,
#  36826.39105364468,
#  36858.448122415335,
#  36863.06019222346,
#  36863.13954297121,
#  36892.45959106038,
#  36974.71244611623,
#  37000.88201388156,
#  37054.83465792435,
#  37155.0557909261,
#  37163.30574188469,
#  37256.59111427768,
#  37289.43424390907,
#  37310.39704785575,
#  37400.74950617284,
#  37541.98846449606,
#  37557.27627660272,
#  37557.27627660272,
#  37630.02374380703,
#  37687.49328332276,
#  37692.65419619066,
#  37702.43215381523,
#  37716.01404855656,
#  37841.66925698837,
#  37856.56664749341,
#  37924.88151315424,
#  38027.602065736486,
#  38086.98154774208,
#  38113.0383372202,
#  38142.39838978537,
#  38227.94787802161,
#  38251.425855415415,
#  38269.795871415634,
#  38299.09033426424,
#  38330.69021449828,
#  38343.26368496254,
#  38381.54676840941,
#  38387.38933354777,
#  38484.08713980381,
#  38494.21319576056,
#  38515.30126401878,
#  38540.39169258657,
#  38596.98079038748,
#  38753.82704959908,
#  38822.99902457785,
#  38845.83139112074,
#  38865.32334839815,
#  39049.29050510695,
#  39083.09667120605,
#  39129.58244810992,
#  39162.14750632163,
#  39424.6038820675,
#  39430.73791200457,
#  39443.912045909616,
#  39445.49779068875,
#  39469.36924890252,
#  39489.319496764045,
#  39535.94304235964,
#  39618.75589992583,
#  39688.767386907166,
#  39688.767386907166,
#  39752.85571096132,
#  39805.67820384291,
#  39834.15597379337,
#  39862.79411243812,
#  39885.470233086045,
#  40065.55519019709,
#  40076.20936615937,
#  40093.29324476177,
#  40103.4771478005,
#  40390.48988991319,
#  40407.83644511882,
#  40466.05692224181,
#  40602.26143970601,
#  40654.98744357939,
#  40769.85464874256,
#  40927.04868709401,
#  40985.17581632468,
#  40994.62768892222,
#  41023.40255211508,
#  41051.36633161632,
#  41096.24909817388,
#  41131.24454804002,
#  41193.89561199889,
#  41198.401435216045,
#  41198.401435216045,
#  41290.53222858941,
#  41293.135164209554,
#  41411.5912450592,
#  41525.14424229219,
#  41527.75671224334,
#  41533.4604483671,
#  41544.86627018438,
#  41596.49912308307,
#  41631.6820614464,
#  41760.49770697656,
#  41791.359611116655,
#  41828.22927475952,
#  41834.450328515966,
#  41837.010377200175,
#  41839.734177819,
#  41895.84570986144,
#  41915.75126968767,
#  41926.07425208676,
#  41931.573790039314,
#  41943.13212678782,
#  41967.04009574125,
#  42037.06323479533,
#  42051.68718548374,
#  42134.29348558493,
#  42143.08908008861,
#  42160.55483024991,
#  42183.5967140883,
#  42197.91610279346,
#  42199.44864874616,
#  42253.07670030612,
#  42272.8070415886,
#  42404.91583675976,
#  42449.432596070576,
#  42474.42461496703,
#  42600.14740118411,
#  42622.39056706285,
#  42731.49753909635,
#  42736.28175676306,
#  42782.50182377749,
#  42805.69568524242,
#  42826.62948232032,
#  42856.379954805336,
#  42877.697301712455,
#  43017.70414546943,
#  43156.18154025881,
#  43233.23673700213,
#  43274.90079121665,
#  43281.88438350507,
#  43294.952940923846,
#  43296.722955243895,
#  43638.24249679691,
#  43640.10027158064,
#  43685.61920944304,
#  43703.92187668799,
#  43710.329388273065,
#  43763.178099961806,
#  43796.214214919855,
#  43843.98273314112,
#  43900.81496657287,
#  43953.84234362926,
#  44014.64618881847,
#  44028.5724209944,
#  44104.8243081132,
#  44151.95762798051,
#  44167.36458586795,
#  44222.65238043452,
#  44258.070118926655,
#  44261.94450504222,
#  44327.311753512346,
#  44432.99031892677,
#  44446.33497319548,
#  44481.11961653071,
#  44613.93333193212,
#  44625.76642955202,
#  44642.22537127064,
#  44693.89426261299,
#  44707.27499280858,
#  44716.02980512054,
#  44719.71191998172,
#  44886.9124724179,
#  45028.91323432792,
#  45029.2840168765,
#  45048.19799608536,
#  45052.47680329297,
#  45298.86869395462,
#  45392.31422095298,
#  45432.57443119217,
#  45630.29224744406,
#  45639.1325345473,
#  45686.02698810511,
#  45719.13092628214,
#  45744.81266790518,
#  45779.25608742399,
#  45795.86149523069,
#  45950.62274356397,
#  45953.48579079028,
#  45987.91498142456,
#  46044.12393236971,
#  46063.42847009423,
#  46193.15431217461,
#  46247.67895584385,
#  46253.77351113448,
#  46283.905146122575,
#  46354.1175951639,
#  46451.30140199911,
#  46467.63541332409,
#  46498.57426376824,
#  46635.81071897379,
#  46638.90303334386,
#  46675.77851286283,
#  46770.23481864212,
#  46895.50291493408,
#  47241.35154001908,
#  47385.22867345735,
#  47403.328553778585,
#  47573.707903237664,
#  47605.90496613883,
#  47805.66167578465,
#  48039.40951571496,
#  48088.90211424882,
#  48114.98174634369,
#  48329.95681460253,
#  48331.84953559581,
#  48416.2838972895,
#  48535.6760894826,
#  48660.80843793279,
#  48827.97726679879,
#  48903.111091182574,
#  48927.30619401163,
#  48929.00815097302,
#  49037.65773814694,
#  49211.01687840592,
#  49511.05958832023,
#  49613.68216139974,
#  49623.361167383104,
#  49879.03576557497,
#  49879.03576557497,
#  49895.13296980831,
#  49902.14130062987,
#  49904.52796585014,
#  49952.74629459321,
#  49959.25553264384,
#  50079.326015856765,
#  50224.20098889598,
#  50440.10793550587,
#  50541.61464636156,
#  50897.39953634672,
#  50956.19251099974,
#  51023.48606272991,
#  51178.14778341791,
#  51255.65731421426,
#  51389.04872218672,
#  51420.47227852182,
#  51420.47227852182,
#  51482.552152869495,
#  51578.137267684346,
#  51601.102748001824,
#  51717.92154115117,
#  51799.72977893714,
#  51869.32850348536,
#  52142.19166080099,
#  52208.52083312832,
#  52301.20703699661,
#  52587.27431459485,
#  52644.936875940606,
#  52719.55359870537,
#  52817.58206647113,
#  52915.85429285647,
#  53356.47810936311,
#  53369.53273729386,
#  53380.19865133474,
#  53428.59637149159,
#  53456.03424074699,
#  53714.31442354803,
#  53737.44545370304,
#  53738.90948222389,
#  54365.73087900318,
#  54439.85004927039,
#  54489.78746545696,
#  54584.11241016285,
#  54966.603809223154,
#  55084.18854130274,
#  55133.21090316728,
#  55196.87527625937,
#  55253.43878097096,
#  55299.58778706516,
#  55299.58778706516,
#  55637.41849467318,
#  55717.90602290598,
#  55717.90602290598,
#  55888.61655528561,
#  55948.36731779753,
#  56238.62433065292,
#  56566.43848965831,
#  56591.86764655074,
#  56613.18756207031,
#  56882.338661409485,
#  57009.879449453496,
#  57311.70565073035,
#  57428.90419597496,
#  57428.90419597496,
#  57564.10099597065,
#  58206.527196039824,
#  59045.83953853365,
#  59470.425719533625,
#  59518.484143922025,
#  59723.687472227866,
#  59868.789024652826,
#  60223.1784168632,
#  60284.49166679795,
#  60425.35788345359,
#  60499.57947905197,
#  60535.17478558135,
#  60737.68384027235,
#  60782.49222013986,
#  60852.7833109653,
#  61199.18885535783,
#  61369.27353636878,
#  61655.315517305935,
#  61896.53383459813,
#  62606.07560202359,
#  63517.18352023964,
#  63617.01853531096,
#  63691.93448904018,
#  63756.82151724405,
#  63793.30323329625,
#  64062.9792155332,
#  64446.64615207783,
#  65333.70387852308,
#  65454.50165513077,
#  66566.54382089595,
#  67020.78273344741,
#  67267.0105296215,
#  67686.11364867479,
#  68155.01842952293,
#  69376.29509432492,
#  69438.18946950408,
#  69493.86655394777,
#  76307.32725297607,
#  77129.50465931698,
#  78645.09966394854,
#  78819.7093973119,
#  106227.69804161054,
#  126940.37563214343,
#  172629.2430273404,
#  260722.6664293028,
#  294554.5395408221,
#  341657.45487248874,
#  361053.7168507165,
#  405632.01211294247,
#  424070.7360754164,
#  536303.701448733,
#  586730.2655809904,
#  663809.0314809685,
#  703648.5720570424,
#  704852.2918350298,
#  716086.9816971098,
#  802454.7848242132,
#  822468.615362943,
#  837197.8961362344,
#  903599.075481328,
#  913216.3465820864,
#  935391.622984103]

# %%
bronze_erp_salary_df = bronze_erp_dates_df

# %%
bronze_erp_salary_df['salario'] = bronze_erp_dates_df['salario'].abs()
# NOTE: Decidimos corregirlo usando el valor absoluto de salario, aunque
# se puede usar cualquier otro método mientras tenga sentido
# Out:
# C:\Users\Alumno\AppData\Local\Temp\ipykernel_9936\2599068689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bronze_erp_salary_df['salario'] = bronze_erp_dates_df['salario'].abs()

# %%
sorted(bronze_erp_salary_df['salario'])
# Out:
# [387.93827496169615,
#  733.2228772671442,
#  1127.8248305600027,
#  1468.431619630108,
#  1617.2362676449957,
#  1682.62741124471,
#  1976.9940006728284,
#  1996.995526057657,
#  2162.4334357451407,
#  2235.89463157098,
#  2341.5154706222493,
#  2354.7096704950964,
#  2484.678426061855,
#  2607.3188435204647,
#  2671.429010214688,
#  2776.9043343866324,
#  2915.9179063985066,
#  3060.5636287685998,
#  3320.5375018529485,
#  3410.8480752626747,
#  3490.5397033413574,
#  3885.272139474389,
#  3927.292914951846,
#  4078.288746389029,
#  4153.690471494119,
#  4557.313984566186,
#  4883.33604258456,
#  5033.590862499419,
#  5111.330724162744,
#  5242.924604877982,
#  5263.76499098666,
#  5527.487679237529,
#  5539.899488771036,
#  5609.833623351704,
#  5765.350130344319,
#  5837.333166573801,
#  6034.321203398868,
#  6110.983734845871,
#  6246.776478187348,
#  6324.245930707024,
#  6475.703568932222,
#  6514.921904576739,
#  6560.178221008824,
#  6650.76043804795,
#  6659.899008394754,
#  6714.338076224078,
#  6768.556168150819,
#  6786.103851483938,
#  6924.450015478451,
#  7000.880944363129,
#  7028.143738264625,
#  7177.08519911531,
#  7177.08519911531,
#  7257.962698451698,
#  7358.67129889856,
#  7527.0429208179485,
#  7761.496535962935,
#  7795.738526888053,
#  7852.312053118163,
#  8069.460427471717,
#  8235.40106338368,
#  8250.897307256211,
#  8383.010702150958,
#  8442.498588865612,
#  8685.231583908313,
#  8854.593456997995,
#  9037.226507341897,
#  9050.567163176587,
#  9180.809091501906,
#  9230.300689580949,
#  9256.995341186626,
#  9291.84982128886,
#  9349.626890428775,
#  9641.1715375983,
#  9856.434025955878,
#  9977.942426715344,
#  10031.553109288943,
#  10080.95229347322,
#  10103.689697115104,
#  10168.510200827135,
#  10245.666388547124,
#  10293.632794709509,
#  10295.02036541526,
#  10315.809219916213,
#  10315.809219916213,
#  10329.409123685213,
#  10350.342625764097,
#  10486.47365228811,
#  10596.620412490523,
#  10954.650193903391,
#  11246.30252819521,
#  11333.124002432494,
#  11380.215023583767,
#  11393.960989093262,
#  11425.56467435931,
#  11427.558377916492,
#  11567.993721717936,
#  11602.768652872652,
#  11610.99952523696,
#  11666.433043866538,
#  11740.427162054806,
#  11812.844630281354,
#  11924.947183514589,
#  11984.547508846124,
#  12058.541522634305,
#  12083.403629914505,
#  12093.256642478147,
#  12096.046345185066,
#  12102.680308518997,
#  12140.27141731949,
#  12172.69917110352,
#  12254.775100018123,
#  12288.269060244917,
#  12382.651762602924,
#  12471.835280150874,
#  12509.866663871624,
#  12518.359946699708,
#  12868.0402585298,
#  12868.101850557396,
#  12888.30886971164,
#  12919.980922936304,
#  13101.797815743044,
#  13135.611086912537,
#  13193.660101325746,
#  13279.719581100304,
#  13325.6200839191,
#  13349.428423628218,
#  13558.154628928973,
#  13569.81654214625,
#  13570.475773952145,
#  13570.748218552577,
#  13764.489918414649,
#  13804.639462464796,
#  13850.085982135057,
#  13871.031176604976,
#  13876.514140363195,
#  13897.984833908216,
#  13931.187754609116,
#  14053.364450258036,
#  14109.118042950842,
#  14109.216842862894,
#  14125.505925613095,
#  14134.265278949186,
#  14272.138301922105,
#  14438.198989293804,
#  14488.482158146038,
#  14555.479765081858,
#  14663.469306813508,
#  14841.088699400892,
#  15193.773445679662,
#  15200.415230406506,
#  15200.415230406506,
#  15315.671308390947,
#  15389.456653231846,
#  15393.75528062886,
#  15493.97634791894,
#  15602.580046295285,
#  15722.24287988064,
#  15773.326908657962,
#  15848.767274874312,
#  15933.302491951345,
#  16036.782087098936,
#  16065.300685160624,
#  16112.712252786312,
#  16153.010843132275,
#  16162.309044343769,
#  16163.509709827817,
#  16375.468035512917,
#  16557.158065250096,
#  16560.01789778247,
#  16567.358967823533,
#  16633.004870977704,
#  16793.070527663913,
#  16814.236722361653,
#  16874.618885156327,
#  16912.27026612193,
#  17069.251778932594,
#  17071.194329762657,
#  17079.244464648844,
#  17128.4168284771,
#  17140.88370387411,
#  17167.329630326203,
#  17363.992761948048,
#  17427.05528985722,
#  17492.472248402966,
#  17527.47085565855,
#  17532.45171293003,
#  17566.07878701117,
#  17573.05846548408,
#  17625.474346012717,
#  17649.611931323656,
#  17720.749805931348,
#  17738.62235968257,
#  17775.540231518356,
#  17831.801792166778,
#  17877.096224243673,
#  17940.34389538895,
#  18006.91618150974,
#  18055.2833632101,
#  18219.7028623192,
#  18239.46187509039,
#  18265.96469510508,
#  18265.96469510508,
#  18284.69356102664,
#  18314.792354494617,
#  18352.772879105352,
#  18463.27164836416,
#  18463.27164836416,
#  18469.705288949364,
#  18495.200847964174,
#  18566.378068056267,
#  18578.067518715747,
#  18593.99888500041,
#  18636.75433141077,
#  18700.52663492164,
#  18761.895634286117,
#  18850.6499555255,
#  18920.53781960896,
#  18980.932957932066,
#  19004.909050850383,
#  19039.77054294329,
#  19058.17955835392,
#  19167.280381095417,
#  19232.649209224168,
#  19237.722208783773,
#  19247.006694636133,
#  19261.24723862201,
#  19359.745680959,
#  19363.10422647131,
#  19397.14298909705,
#  19474.386028126875,
#  19494.7678881307,
#  19533.99325047579,
#  19545.903823791425,
#  19567.9615301758,
#  19591.97518787973,
#  19610.07663254846,
#  19625.736452716486,
#  19636.793815706853,
#  19661.56394674715,
#  19696.263663112688,
#  19705.213865263264,
#  19769.484252010283,
#  19822.059969528866,
#  19837.865145042557,
#  19852.42317826296,
#  19860.205905384035,
#  19937.45944899758,
#  20146.34099253789,
#  20270.06119426695,
#  20355.02664778682,
#  20424.84209785496,
#  20566.06663216961,
#  20581.25216102876,
#  20645.918476061903,
#  20687.32171076036,
#  20793.04684735685,
#  20826.4212398459,
#  20889.816018518177,
#  20948.665518604164,
#  20971.69183198149,
#  21022.595749254964,
#  21073.47308767921,
#  21080.91249240742,
#  21142.828971834373,
#  21142.828971834373,
#  21145.86774960326,
#  21187.532775423853,
#  21248.814661978056,
#  21281.472403757514,
#  21288.333172440427,
#  21299.579962673408,
#  21300.944461306117,
#  21311.1715073573,
#  21313.795372808552,
#  21483.67405238709,
#  21492.11371780983,
#  21495.585366701343,
#  21498.072404308517,
#  21676.92430843864,
#  21707.474480682307,
#  21736.332261677195,
#  21739.09463867044,
#  21793.57053919348,
#  21806.097434536543,
#  21861.015533533857,
#  21900.98310691724,
#  22003.441127032296,
#  22042.385655927646,
#  22070.06994994257,
#  22075.815398970302,
#  22090.71083639669,
#  22105.582031595397,
#  22140.051398169653,
#  22171.472787252675,
#  22202.19912676869,
#  22223.956508767173,
#  22256.159760943094,
#  22256.368694862595,
#  22265.03949236683,
#  22315.054883665445,
#  22328.241666746533,
#  22384.80326301507,
#  22390.00836917181,
#  22400.84239950573,
#  22461.008090906515,
#  22510.54140642004,
#  22562.12383894781,
#  22593.441333772516,
#  22593.60086459316,
#  22614.73481790659,
#  22620.399462913203,
#  22663.578211216394,
#  22734.585835914662,
#  22769.298077576743,
#  22878.39531774438,
#  22898.12859551461,
#  22922.106083498045,
#  22956.71731408,
#  22960.898928678293,
#  22971.256021349764,
#  22977.25813036433,
#  23035.194832538004,
#  23113.63404668121,
#  23126.75221049137,
#  23144.424962064048,
#  23248.48299464664,
#  23370.477041186867,
#  23471.93507074549,
#  23477.613571346326,
#  23501.101747686844,
#  23757.08995904789,
#  23794.362484880723,
#  23818.91316474316,
#  23845.778460435045,
#  23903.066681559576,
#  24025.186409640573,
#  24037.052685668103,
#  24158.731837604435,
#  24239.51733179789,
#  24303.63990029637,
#  24310.05120242507,
#  24328.708485249983,
#  24335.23707998165,
#  24340.826911744665,
#  24392.58908925852,
#  24442.40547465721,
#  24532.99106219657,
#  24536.962747680936,
#  24558.93129773328,
#  24575.320834715145,
#  24579.21349227243,
#  24592.28674914165,
#  24597.096080850784,
#  24599.51828017709,
#  24643.464452883905,
#  24652.92543947504,
#  24800.50224763767,
#  24815.85727954952,
#  24848.83350618049,
#  24914.320451853917,
#  24917.10494850961,
#  24958.890207749453,
#  25071.97637305902,
#  25167.90637214904,
#  25188.37750640582,
#  25206.648565213796,
#  25214.884998707643,
#  25247.673580623035,
#  25338.68292328801,
#  25393.57672933348,
#  25404.69808843036,
#  25454.525385029563,
#  25462.99742688973,
#  25471.73242214172,
#  25704.12189754835,
#  25733.798108818195,
#  25769.71603855447,
#  25864.09121299011,
#  25867.345642973985,
#  25927.13286762926,
#  25941.00162504945,
#  25972.97594562532,
#  26070.503455221708,
#  26086.316008243048,
#  26123.989196892475,
#  26136.896699073768,
#  26161.779634942024,
#  26193.79978758624,
#  26245.21932400509,
#  26410.54834800872,
#  26421.99829736,
#  26468.765671301677,
#  26506.59880144352,
#  26539.493802067827,
#  26661.872461284027,
#  26703.89544895685,
#  26720.689332619037,
#  26734.03523267329,
#  27018.914459750653,
#  27032.92971155241,
#  27070.53456626859,
#  27152.962203788687,
#  27163.7779625719,
#  27204.553951845217,
#  27208.164783717457,
#  27380.432222851046,
#  27384.374544520346,
#  27391.70037616248,
#  27455.488213572677,
#  27458.261437749487,
#  27466.48829538843,
#  27468.04819946782,
#  27479.174014674525,
#  27533.75339307928,
#  27683.01721698036,
#  27795.01826704391,
#  27842.313436320543,
#  27847.314834668825,
#  27917.061192079924,
#  28093.02837522004,
#  28110.915405797496,
#  28143.1561828362,
#  28144.074955992404,
#  28154.791149646346,
#  28201.9117886569,
#  28314.69162794429,
#  28350.934269447247,
#  28379.434503161243,
#  28401.078586280222,
#  28409.07136442942,
#  28432.779804347003,
#  28457.467196634007,
#  28472.763869556456,
#  28540.3771684196,
#  28571.323826619824,
#  28588.46027310725,
#  28685.42613275284,
#  28813.818785904725,
#  28820.73542187772,
#  28825.940042948776,
#  28877.19921097729,
#  28904.49780271796,
#  28928.315143518288,
#  28989.13146422709,
#  28992.246290071245,
#  29002.07223671951,
#  29050.66318291555,
#  29051.648152755617,
#  29207.100685630496,
#  29359.443079150748,
#  29384.768684948045,
#  29403.91642790738,
#  29451.999751220843,
#  29460.06882034137,
#  29479.450199551648,
#  29547.425000562976,
#  29548.267993498503,
#  29584.93998608608,
#  29725.24710835723,
#  29754.01835616317,
#  29787.029633829912,
#  29848.261327966327,
#  29884.061666178928,
#  29960.974985864723,
#  30087.785050880648,
#  30102.04647589157,
#  30150.34953363381,
#  30281.70456474674,
#  30372.785073669664,
#  30391.83647309589,
#  30419.2718286669,
#  30446.68894851936,
#  30457.432571303973,
#  30495.40564448696,
#  30527.218221367628,
#  30866.933783778288,
#  30893.29452470423,
#  30900.435086280184,
#  30947.481889607603,
#  31046.688202481968,
#  31135.08441070853,
#  31175.230034438908,
#  31185.001254165934,
#  31216.503660600323,
#  31234.94830075631,
#  31287.60595089755,
#  31412.69162520613,
#  31424.99825245556,
#  31498.583158536145,
#  31592.681517333174,
#  31657.35808049203,
#  31662.316427007045,
#  31664.34144102065,
#  31708.794421511546,
#  31886.267588031304,
#  31926.77606396629,
#  31939.604627495108,
#  31971.87601171831,
#  32130.76416486914,
#  32189.42414569725,
#  32243.962171103307,
#  32252.019510093272,
#  32270.96531839811,
#  32314.756899544213,
#  32421.59794931548,
#  32445.91601144124,
#  32452.1621875118,
#  32453.60003382982,
#  32536.860751486354,
#  32562.47847619946,
#  32564.564573523287,
#  32581.820585031644,
#  32610.278349309054,
#  32647.30965543938,
#  32691.25219246903,
#  32695.776796476737,
#  32723.80268923185,
#  32742.10363808005,
#  32811.29820785155,
#  32826.24012446142,
#  32839.31841353333,
#  32839.31841353333,
#  32844.42184958179,
#  32900.93674742611,
#  32930.62926527616,
#  33075.40030592818,
#  33136.03845176798,
#  33147.27193065063,
#  33148.68134462805,
#  33158.550509376975,
#  33174.614662629734,
#  33191.1725768961,
#  33258.214644710155,
#  33449.316717633184,
#  33464.00161244992,
#  33474.720232259744,
#  33485.404165258,
#  33512.063206699444,
#  33546.37014393673,
#  33654.487500110605,
#  33659.464819188666,
#  33679.16756667645,
#  33686.0097438203,
#  33705.3996540767,
#  33712.46695255816,
#  33773.56627248479,
#  33888.2702751489,
#  33903.9833755159,
#  33958.416456810286,
#  34100.645219164006,
#  34100.645219164006,
#  34155.941256562684,
#  34171.59028637941,
#  34174.93591830322,
#  34233.11464334902,
#  34289.774110836894,
#  34371.74884817709,
#  34459.64468521263,
#  34468.42374718035,
#  34470.78315160763,
#  34502.33377493588,
#  34502.88243900292,
#  34525.42702419061,
#  34535.00612645001,
#  34535.98266357337,
#  34556.70464235758,
#  34681.19128229504,
#  34751.130882066565,
#  34837.36073509226,
#  34877.00472947657,
#  34911.29657476482,
#  34939.73677727664,
#  35017.48802667177,
#  35042.40069414062,
#  35082.97735577614,
#  35101.76559606967,
#  35124.43829053672,
#  35125.93372110652,
#  35136.41647831912,
#  35157.67234686449,
#  35237.58810467785,
#  35273.219382388335,
#  35298.11091761765,
#  35300.89256395362,
#  35336.89462391493,
#  35417.17155520303,
#  35453.1891103104,
#  35582.53022208143,
#  35616.5448893186,
#  35669.42189905311,
#  35698.01776063622,
#  35700.711951885394,
#  35705.37795575874,
#  35727.58591261476,
#  35733.82408717378,
#  35736.62126728948,
#  35856.035158744,
#  35886.97711689883,
#  35908.67959854229,
#  35922.386166115524,
#  36091.27795524351,
#  36157.13765841685,
#  36272.80617701623,
#  36273.09919131804,
#  36320.39352073502,
#  36330.19741060453,
#  36379.93590714891,
#  36397.43728379533,
#  36439.96532729853,
#  36458.59008141074,
#  36482.88977198107,
#  36494.65024091597,
#  36496.80802015791,
#  36546.37694239618,
#  36642.09571531373,
#  36731.70777849775,
#  36735.16445128404,
#  36774.490524743946,
#  36824.5783590146,
#  36826.39105364468,
#  36858.448122415335,
#  36863.06019222346,
#  36863.13954297121,
#  36892.45959106038,
#  36974.71244611623,
#  37000.88201388156,
#  37054.83465792435,
#  37155.0557909261,
#  37163.30574188469,
#  37256.59111427768,
#  37289.43424390907,
#  37310.39704785575,
#  37400.74950617284,
#  37541.98846449606,
#  37557.27627660272,
#  37557.27627660272,
#  37630.02374380703,
#  37687.49328332276,
#  37692.65419619066,
#  37702.43215381523,
#  37716.01404855656,
#  37841.66925698837,
#  37856.56664749341,
#  37924.88151315424,
#  38027.602065736486,
#  38086.98154774208,
#  38113.0383372202,
#  38142.39838978537,
#  38227.94787802161,
#  38251.425855415415,
#  38269.795871415634,
#  38299.09033426424,
#  38330.69021449828,
#  38343.26368496254,
#  38381.54676840941,
#  38387.38933354777,
#  38484.08713980381,
#  38494.21319576056,
#  38515.30126401878,
#  38540.39169258657,
#  38596.98079038748,
#  38753.82704959908,
#  38822.99902457785,
#  38845.83139112074,
#  38865.32334839815,
#  39049.29050510695,
#  39083.09667120605,
#  39129.58244810992,
#  39162.14750632163,
#  39424.6038820675,
#  39430.73791200457,
#  39443.912045909616,
#  39445.49779068875,
#  39469.36924890252,
#  39489.319496764045,
#  39535.94304235964,
#  39618.75589992583,
#  39688.767386907166,
#  39688.767386907166,
#  39752.85571096132,
#  39805.67820384291,
#  39834.15597379337,
#  39862.79411243812,
#  39885.470233086045,
#  40065.55519019709,
#  40076.20936615937,
#  40093.29324476177,
#  40103.4771478005,
#  40390.48988991319,
#  40407.83644511882,
#  40466.05692224181,
#  40602.26143970601,
#  40654.98744357939,
#  40769.85464874256,
#  40927.04868709401,
#  40985.17581632468,
#  40994.62768892222,
#  41023.40255211508,
#  41051.36633161632,
#  41096.24909817388,
#  41131.24454804002,
#  41193.89561199889,
#  41198.401435216045,
#  41198.401435216045,
#  41290.53222858941,
#  41293.135164209554,
#  41411.5912450592,
#  41525.14424229219,
#  41527.75671224334,
#  41533.4604483671,
#  41544.86627018438,
#  41596.49912308307,
#  41631.6820614464,
#  41760.49770697656,
#  41791.359611116655,
#  41828.22927475952,
#  41834.450328515966,
#  41837.010377200175,
#  41839.734177819,
#  41895.84570986144,
#  41915.75126968767,
#  41926.07425208676,
#  41931.573790039314,
#  41943.13212678782,
#  41967.04009574125,
#  42037.06323479533,
#  42051.68718548374,
#  42134.29348558493,
#  42143.08908008861,
#  42160.55483024991,
#  42183.5967140883,
#  42197.91610279346,
#  42199.44864874616,
#  42253.07670030612,
#  42272.8070415886,
#  42404.91583675976,
#  42449.432596070576,
#  42474.42461496703,
#  42600.14740118411,
#  42622.39056706285,
#  42731.49753909635,
#  42736.28175676306,
#  42782.50182377749,
#  42805.69568524242,
#  42826.62948232032,
#  42856.379954805336,
#  42877.697301712455,
#  43017.70414546943,
#  43156.18154025881,
#  43233.23673700213,
#  43274.90079121665,
#  43281.88438350507,
#  43294.952940923846,
#  43296.722955243895,
#  43638.24249679691,
#  43640.10027158064,
#  43685.61920944304,
#  43703.92187668799,
#  43710.329388273065,
#  43763.178099961806,
#  43796.214214919855,
#  43843.98273314112,
#  43900.81496657287,
#  43953.84234362926,
#  44014.64618881847,
#  44028.5724209944,
#  44104.8243081132,
#  44151.95762798051,
#  44167.36458586795,
#  44222.65238043452,
#  44258.070118926655,
#  44261.94450504222,
#  44327.311753512346,
#  44432.99031892677,
#  44446.33497319548,
#  44481.11961653071,
#  44613.93333193212,
#  44625.76642955202,
#  44642.22537127064,
#  44693.89426261299,
#  44707.27499280858,
#  44716.02980512054,
#  44719.71191998172,
#  44886.9124724179,
#  45028.91323432792,
#  45029.2840168765,
#  45048.19799608536,
#  45052.47680329297,
#  45298.86869395462,
#  45392.31422095298,
#  45432.57443119217,
#  45630.29224744406,
#  45639.1325345473,
#  45686.02698810511,
#  45719.13092628214,
#  45744.81266790518,
#  45779.25608742399,
#  45795.86149523069,
#  45950.62274356397,
#  45953.48579079028,
#  45987.91498142456,
#  46044.12393236971,
#  46063.42847009423,
#  46193.15431217461,
#  46247.67895584385,
#  46253.77351113448,
#  46283.905146122575,
#  46354.1175951639,
#  46451.30140199911,
#  46467.63541332409,
#  46498.57426376824,
#  46635.81071897379,
#  46638.90303334386,
#  46675.77851286283,
#  46770.23481864212,
#  46895.50291493408,
#  47241.35154001908,
#  47385.22867345735,
#  47403.328553778585,
#  47573.707903237664,
#  47605.90496613883,
#  47805.66167578465,
#  48039.40951571496,
#  48088.90211424882,
#  48114.98174634369,
#  48329.95681460253,
#  48331.84953559581,
#  48416.2838972895,
#  48535.6760894826,
#  48660.80843793279,
#  48827.97726679879,
#  48903.111091182574,
#  48927.30619401163,
#  48929.00815097302,
#  49037.65773814694,
#  49211.01687840592,
#  49511.05958832023,
#  49613.68216139974,
#  49623.361167383104,
#  49747.0817562402,
#  49879.03576557497,
#  49879.03576557497,
#  49895.13296980831,
#  49902.14130062987,
#  49904.52796585014,
#  49952.74629459321,
#  49959.25553264384,
#  50079.326015856765,
#  50224.20098889598,
#  50440.10793550587,
#  50541.61464636156,
#  50897.39953634672,
#  50956.19251099974,
#  51023.48606272991,
#  51178.14778341791,
#  51255.65731421426,
#  51389.04872218672,
#  51420.47227852182,
#  51420.47227852182,
#  51482.552152869495,
#  51578.137267684346,
#  51601.102748001824,
#  51717.92154115117,
#  51799.72977893714,
#  51869.32850348536,
#  52142.19166080099,
#  52208.52083312832,
#  52301.20703699661,
#  52587.27431459485,
#  52644.936875940606,
#  52719.55359870537,
#  52817.58206647113,
#  52915.85429285647,
#  53356.47810936311,
#  53369.53273729386,
#  53380.19865133474,
#  53428.59637149159,
#  53456.03424074699,
#  53714.31442354803,
#  53737.44545370304,
#  53738.90948222389,
#  54365.73087900318,
#  54439.85004927039,
#  54489.78746545696,
#  54584.11241016285,
#  54966.603809223154,
#  55084.18854130274,
#  55133.21090316728,
#  55196.87527625937,
#  55253.43878097096,
#  55299.58778706516,
#  55299.58778706516,
#  55637.41849467318,
#  55717.90602290598,
#  55717.90602290598,
#  55888.61655528561,
#  55948.36731779753,
#  56238.62433065292,
#  56566.43848965831,
#  56591.86764655074,
#  56613.18756207031,
#  56882.338661409485,
#  57009.879449453496,
#  57311.70565073035,
#  57428.90419597496,
#  57428.90419597496,
#  57564.10099597065,
#  58206.527196039824,
#  59045.83953853365,
#  59470.425719533625,
#  59518.484143922025,
#  59723.687472227866,
#  59868.789024652826,
#  60223.1784168632,
#  60284.49166679795,
#  60425.35788345359,
#  60499.57947905197,
#  60535.17478558135,
#  60737.68384027235,
#  60782.49222013986,
#  60852.7833109653,
#  61199.18885535783,
#  61369.27353636878,
#  61655.315517305935,
#  61896.53383459813,
#  62606.07560202359,
#  63517.18352023964,
#  63617.01853531096,
#  63691.93448904018,
#  63756.82151724405,
#  63793.30323329625,
#  64062.9792155332,
#  64446.64615207783,
#  65333.70387852308,
#  65454.50165513077,
#  66566.54382089595,
#  67020.78273344741,
#  67267.0105296215,
#  67686.11364867479,
#  68155.01842952293,
#  69376.29509432492,
#  69438.18946950408,
#  69493.86655394777,
#  76307.32725297607,
#  77129.50465931698,
#  78645.09966394854,
#  78819.7093973119,
#  106227.69804161054,
#  126940.37563214343,
#  172629.2430273404,
#  260722.6664293028,
#  294554.5395408221,
#  341657.45487248874,
#  361053.7168507165,
#  405632.01211294247,
#  424070.7360754164,
#  536303.701448733,
#  586730.2655809904,
#  663809.0314809685,
#  703648.5720570424,
#  704852.2918350298,
#  716086.9816971098,
#  802454.7848242132,
#  822468.615362943,
#  837197.8961362344,
#  903599.075481328,
#  913216.3465820864,
#  935391.622984103]

# %%
bronze_erp_salary_df.info() # Comprobamos el tipo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 969 entries, 0 to 1019
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_cliente        969 non-null    int64
#  1   nombre            969 non-null    object
#  2   email             969 non-null    object
#  3   edad              902 non-null    float64
#  4   ciudad            969 non-null    object
#  5   salario           969 non-null    float64
#  6   fecha_registro    969 non-null    object
#  7   categoria         969 non-null    object
#  8   telefono          969 non-null    object
#  9   activo            969 non-null    object
#  10  puntos_fidelidad  969 non-null    float64
#  11  ultima_compra     969 non-null    object
#  12  _BronzeTimestamp  969 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(3), int64(1), object(8)
# memory usage: 106.0+ KB

# %%
bronze_erp_salary_df['ultima_compra'].value_counts(dropna=False)
# NOTE: No todos los valores en esta columna de timestamps son timestamps
# Out:
# ultima_compra
# No registrada                 47
# 2025-04-03 22:25:26.835945     4
# 2025-10-08 22:25:26.834944     3
# 2023-11-14 22:25:26.834944     3
# 2024-10-06 22:25:26.834944     3
#                               ..
# 2024-03-11 22:25:26.836945     1
# 2024-12-06 22:25:26.836945     1
# 2024-06-18 22:25:26.836945     1
# 2025-09-05 22:25:26.833943     1
# 2024-12-23 22:25:26.833943     1
# Name: count, Length: 772, dtype: int64

# %%
bronze_erp_ultima_compra_df = bronze_erp_salary_df

# %%
# NOTE: Decidimos corregirlo usando la fecha de registro como fecha de ultima_compra
# para los valores inválidos

# %%
def reemplazar_fechas_erroneas(fila: dict)->None:
    if fila['ultima_compra'] == "No registrada":
        return fila['fecha_registro']
    else:
        return fila['ultima_compra']

# %%
bronze_erp_ultima_compra_df = bronze_erp_ultima_compra_df.apply(reemplazar_fechas_erroneas, axis=1)

# %%
bronze_erp_ultima_compra_df['ultima_compra'].value_counts(dropna=False)
# Out:
# ultima_compra
# 2025-04-03 22:25:26.835945    4
# 2024-01-24 22:25:26.835945    3
# 2025-10-08 22:25:26.834944    3
# 2024-05-10 22:25:26.834944    3
# 2025-02-21 22:25:26.834944    3
#                              ..
# 2024-03-11 22:25:26.836945    1
# 2024-12-06 22:25:26.836945    1
# 2024-06-18 22:25:26.836945    1
# 2025-09-05 22:25:26.833943    1
# 2025-07-12 22:25:26.836945    1
# Name: count, Length: 818, dtype: int64

# %%
bronze_erp_category =bronze_erp_ultima_compra_df

# %%
bronze_erp_category['categoria'].value_counts(dropna=False)
# Out:
# categoria
# INVALID    146
# G          126
# F          125
# C          124
# D          121
# E          118
# B          110
# A           99
# Name: count, dtype: int64

# %%
bronze_erp_activo_df = bronze_erp_category

# %%
bronze_erp_activo_df['activo'].value_counts(dropna=False)
# NOTE: Pese a que todos los valores de activo son representaciones
# de un booleano, no son el mismo booleano, por lo que debemos normalizar
# Out:
# activo
# False    193
# True     169
# 0        165
# 1        160
# Sí       142
# No       140
# Name: count, dtype: int64

# %%
def normalizar_booleano(valor: str)->str:
    valores_truthy = ["Sí","1","True"]
    valores_falsy = ["No","0","False"]
    if valor in valores_truthy:
        return True
    elif valor in valores_falsy:
        return False
    else:
        return valor

# %%
bronze_erp_activo_df['activo'] = bronze_erp_activo_df['activo'].apply(normalizar_booleano)
# Out:
# C:\Users\Alumno\AppData\Local\Temp\ipykernel_9936\1779153276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bronze_erp_activo_df['activo'] = bronze_erp_activo_df['activo'].apply(normalizar_booleano)

# %%
bronze_erp_activo_df['activo'].value_counts(dropna=False)
# Out:
# activo
# False    498
# True     471
# Name: count, dtype: int64

# %% [markdown]
# ### Duplicados
#
# Al igual que con los nulos, las columnas críticas (claves primarias) no pueden tener dos filas representando el mismo cliente.
#
# En caso de no tener claves primarias, usaremos nuestro criterio para saber que puede o no puede estar duplicado en nuestro dataset.

# %%
bronze_erp_activo_df['id_cliente'].value_counts()
# Out:
# id_cliente
# 466     2
# 283     2
# 75      2
# 211     2
# 473     2
#        ..
# 997     1
# 998     1
# 999     1
# 1000    1
# 6       1
# Name: count, Length: 950, dtype: int64

# %%
bronze_erp_activo_df['id_cliente'].count()
# Out:
# np.int64(969)

# %%
bronze_erp_sin_duplicados_df = bronze_erp_activo_df.drop_duplicates("id_cliente")

# %%
bronze_erp_sin_duplicados_df['id_cliente'].value_counts()
# Out:
# id_cliente
# 1       1
# 2       1
# 3       1
# 4       1
# 5       1
#        ..
# 997     1
# 998     1
# 999     1
# 1000    1
# 642     1
# Name: count, Length: 950, dtype: int64

# %%
bronze_erp_sin_duplicados_df['id_cliente'].count()
# Out:
# np.int64(950)

# %%
bronze_erp_sin_duplicados_df = bronze_erp_activo_df.drop_duplicates(["nombre","email"])

# %%
bronze_erp_sin_duplicados_df['id_cliente'].count()
# Out:
# np.int64(948)

# %% [markdown]
# ### Tipado
#
# Para asegurar que las operaciones entre columnas son lo más eficientes posible, y que no nos encontraremos en una situación:
#
# "2" + "2" = "22"
#
# Es importante comprobar que todas las columnas tienen el tipo correcto, y corregirlo en caso de que no.

# %%
bronze_erp_sin_duplicados_df.info()
# NOTE: Podemos ver que está todo bien menos las columnas de fecha
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 948 entries, 0 to 1010
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_cliente        948 non-null    int64
#  1   nombre            948 non-null    object
#  2   email             948 non-null    object
#  3   edad              882 non-null    float64
#  4   ciudad            948 non-null    object
#  5   salario           948 non-null    float64
#  6   fecha_registro    948 non-null    object
#  7   categoria         948 non-null    object
#  8   telefono          948 non-null    object
#  9   activo            948 non-null    bool
#  10  puntos_fidelidad  948 non-null    float64
#  11  ultima_compra     948 non-null    object
#  12  _BronzeTimestamp  948 non-null    datetime64[us]
# dtypes: bool(1), datetime64[us](1), float64(3), int64(1), object(7)
# memory usage: 97.2+ KB

# %%
bronze_erp_sin_duplicados_df['ultima_compra'] = pd.to_datetime(bronze_erp_sin_duplicados_df['ultima_compra'])
# Out:
# C:\Users\Alumno\AppData\Local\Temp\ipykernel_9936\4279201018.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bronze_erp_sin_duplicados_df['ultima_compra'] = pd.to_datetime(bronze_erp_sin_duplicados_df['ultima_compra'])

# %%
bronze_erp_sin_duplicados_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 948 entries, 0 to 1010
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_cliente        948 non-null    int64
#  1   nombre            948 non-null    object
#  2   email             948 non-null    object
#  3   edad              882 non-null    float64
#  4   ciudad            948 non-null    object
#  5   salario           948 non-null    float64
#  6   fecha_registro    948 non-null    object
#  7   categoria         948 non-null    object
#  8   telefono          948 non-null    object
#  9   activo            948 non-null    bool
#  10  puntos_fidelidad  948 non-null    float64
#  11  ultima_compra     948 non-null    datetime64[ns]
#  12  _BronzeTimestamp  948 non-null    datetime64[us]
# dtypes: bool(1), datetime64[ns](1), datetime64[us](1), float64(3), int64(1), object(6)
# memory usage: 97.2+ KB

# %%
bronze_erp_sin_duplicados_df['fecha_registro'] = pd.to_datetime(bronze_erp_sin_duplicados_df['fecha_registro'])
# Out:
# C:\Users\Alumno\AppData\Local\Temp\ipykernel_9936\3497994002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bronze_erp_sin_duplicados_df['fecha_registro'] = pd.to_datetime(bronze_erp_sin_duplicados_df['fecha_registro'])

# %%
bronze_erp_sin_duplicados_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 948 entries, 0 to 1010
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_cliente        948 non-null    int64
#  1   nombre            948 non-null    object
#  2   email             948 non-null    object
#  3   edad              882 non-null    float64
#  4   ciudad            948 non-null    object
#  5   salario           948 non-null    float64
#  6   fecha_registro    948 non-null    datetime64[ns]
#  7   categoria         948 non-null    object
#  8   telefono          948 non-null    object
#  9   activo            948 non-null    bool
#  10  puntos_fidelidad  948 non-null    float64
#  11  ultima_compra     948 non-null    datetime64[ns]
#  12  _BronzeTimestamp  948 non-null    datetime64[us]
# dtypes: bool(1), datetime64[ns](2), datetime64[us](1), float64(3), int64(1), object(5)
# memory usage: 97.2+ KB

# %% [markdown]
# ### Guardar

# %%
# Crear carpeta
os.mkdir(silver_path)

# %%
bronze_erp_sin_duplicados_df.to_parquet(silver_file_path)
